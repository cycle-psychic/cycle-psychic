# %%
# Import package pandas for data analysis
# Set to display enough columns
import pandas as pd
pd.set_option('display.max_columns', 100)

# Import package numpy for numeric computing
import numpy as np

# Import package matplotlib for visualisation/plotting
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# Import to allow PDF of multiple pages
from matplotlib.backends.backend_pdf import PdfPages

# Import Seaborn for visualistaion library
import seaborn as sns

# Import to allow date to be converted to day of the week
import datetime

#For showing plots directly in the notebook run the command below
# %matplotlib inline

# %%
# Read in csv file. Header not included with data so added here.
parse_date = ['last_update']
df = pd.read_csv('05-13-03-19_results.csv', names=['address', 'contract_name', 'name', 'last_update', 'lng', 'lat', 'status', 'available_bikes', 'bonus', 'available_bike_stands', 'number', 'bike_stands', 'banking'], parse_dates=parse_date)

# %%
# Check how many rows and columns the dataframe has
print ('The file has', df.shape[0], 'rows and', df.shape[1], 'columns')
# Out:
# The file has 163006 rows and 13 columns

# %%
df.head(5)
# Out:
#               address contract_name                name         last_update  \
# 0  Blessington Street        Dublin  BLESSINGTON STREET 2019-03-05 00:05:08
# 1  Blessington Street        Dublin  BLESSINGTON STREET 2019-03-05 00:15:17
# 2  Blessington Street        Dublin  BLESSINGTON STREET 2019-03-05 00:25:26
# 3  Blessington Street        Dublin  BLESSINGTON STREET 2019-03-05 00:32:29
# 4  Blessington Street        Dublin  BLESSINGTON STREET 2019-03-05 00:42:39
#
#        lng        lat status  available_bikes  bonus  available_bike_stands  \
# 0 -6.26814  53.356769   OPEN               14      0                      6
# 1 -6.26814  53.356769   OPEN               14      0                      6
# 2 -6.26814  53.356769   OPEN               14      0                      6
# 3 -6.26814  53.356769   OPEN               14      0                      6
# 4 -6.26814  53.356769   OPEN               14      0                      6
#
#    number  bike_stands  banking
# 0       2           20        1
# 1       2           20        1
# 2       2           20        1
# 3       2           20        1
# 4       2           20        1

# %% [markdown]
# Date and time will need to be seperated in to columns. One for hours, one for minutes and one for day of the week. Make three new columns.

# %%
# Check for duplicate rows - numerical only, does not show values
print('Duplicate rows:', df.duplicated()[df.duplicated() == True].shape[0])
# Check for duplicate columns - numerical only, does not show values
print('Duplicate columns:',df.columns.size - df.columns.unique().size)
# Out:
# Duplicate rows: 0
# Duplicate columns: 0

# %%
# Convert date to a day of the week in a new column. 
# Create new column with hour
# Create new column with minute

df['weekday'] = df['last_update']
df['hour'] = df['last_update']
df['minute'] = df['last_update']

df['weekday'] = df['weekday'].apply(lambda date: datetime.datetime.weekday(date))
df['hour'] = df['hour'].apply(lambda time: time.hour)
df['minute'] = df['minute'].apply(lambda time: time.minute)

# %% [markdown]
# **Note: The weekday column goes from 0 to 6. 0 is Monday and 6 is Sunday.**

# %%
# Check data types
df.dtypes
# Out:
# address                          object
# contract_name                    object
# name                             object
# last_update              datetime64[ns]
# lng                             float64
# lat                             float64
# status                           object
# available_bikes                   int64
# bonus                             int64
# available_bike_stands             int64
# number                            int64
# bike_stands                       int64
# banking                           int64
# weekday                           int64
# hour                              int64
# minute                            int64
# dtype: object

# %%
categorical_columns = df[['address', 'contract_name', 'name', 'last_update', 'status']]
for column in categorical_columns:
    df[column] = df[column].astype('category')

# %%
# Select columns with continuous data.
df.select_dtypes(['float64', 'int64']).describe().T
# Out:
#                           count       mean        std        min        25%  \
# lng                    163006.0  -6.263823   0.017867  -6.310015  -6.275071
# lat                    163006.0  53.345367   0.007472  53.330091  53.339764
# available_bikes        163006.0  11.056341  10.692027   0.000000   2.000000
# bonus                  163006.0   0.000000   0.000000   0.000000   0.000000
# available_bike_stands  163006.0  20.691588  11.681105   0.000000  12.000000
# number                 163006.0  57.416445  32.578302   2.000000  30.000000
# bike_stands            163006.0  31.980093   7.521530  16.000000  29.000000
# banking                163006.0   0.331203   0.470647   0.000000   0.000000
# weekday                163006.0   2.683380   1.949596   0.000000   1.000000
# hour                   163006.0  11.867355   6.617178   0.000000   7.000000
# minute                 163006.0  29.493522  17.333274   0.000000  14.000000
#
#                              50%       75%         max
# lng                    -6.262980  -6.25090   -6.230852
# lat                    53.344603  53.35023   53.359967
# available_bikes         8.000000  18.00000   40.000000
# bonus                   0.000000   0.00000    0.000000
# available_bike_stands  20.000000  30.00000   40.000000
# number                 57.000000  85.00000  115.000000
# bike_stands            30.000000  40.00000   40.000000
# banking                 0.000000   1.00000    1.000000
# weekday                 2.000000   4.00000    6.000000
# hour                   12.000000  17.00000   23.000000
# minute                 30.000000  44.00000   59.000000

# %%
# Check for any columns with missing values
df.isnull().sum()
# Out:
# address                  0
# contract_name            0
# name                     0
# last_update              0
# lng                      0
# lat                      0
# status                   0
# available_bikes          0
# bonus                    0
# available_bike_stands    0
# number                   0
# bike_stands              0
# banking                  0
# weekday                  0
# hour                     0
# minute                   0
# dtype: int64

# %%
# Shows the median of each continuous column
df.select_dtypes(['float64', 'int64']).median()
# Out:
# lng                      -6.262980
# lat                      53.344603
# available_bikes           8.000000
# bonus                     0.000000
# available_bike_stands    20.000000
# number                   57.000000
# bike_stands              30.000000
# banking                   0.000000
# weekday                   2.000000
# hour                     12.000000
# minute                   30.000000
# dtype: float64

# %%
# Check the cardinality of continuous features
df.select_dtypes(['float64', 'int64']).nunique()
# Out:
# lng                      113
# lat                      113
# available_bikes           41
# bonus                      1
# available_bike_stands     41
# number                   113
# bike_stands               18
# banking                    2
# weekday                    7
# hour                      24
# minute                    60
# dtype: int64

# %%
# Drop the bonus as only a single value
df.drop(['bonus'], axis=1, inplace = True)

# %%
# Print table with descriptive statistics for all the categorical features
df.select_dtypes(['category']).describe().T
# Out:
#                 count  unique                                top    freq
# address        163006     113  Princes Street / O'Connell Street    1767
# contract_name  163006       1                             Dublin  163006
# name           163006     113  PRINCES STREET / O'CONNELL STREET    1767
# last_update    163006  136002                2019-03-12 22:14:42      34
# status         163006       1                               OPEN  163006

# %% [markdown]
# Can drop contract name and status as only a single value for each

# %%
# Drop categorical columns with a single value
df.drop(['status', 'contract_name'], axis=1, inplace = True)

# %%
# View histogram of continuous columns. Banking and weekday will be shown on bar chart
continuous_columns = df[['lng', 'lat', 'available_bikes', 'available_bike_stands',
                        'number', 'bike_stands', 'hour', 'minute']].columns

df[continuous_columns].hist(figsize=(30,30))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a1dbd8198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1d2894a8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1af44390>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1b8cf7f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1df102b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1e0bbda0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1b8e16a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1d447be0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1d447a20>]],
#       dtype=object)

# %%
for column in continuous_columns:
    df[column].plot(kind = 'box', figsize=(10,5))
    plt.show()

# %%
bar_chart_columns = df [['banking', 'weekday', 'address', 'name']]

for column in bar_chart_columns:
    df[column].value_counts().plot(kind='bar', title=column, figsize=(10,5))
    plt.show()

# %% [markdown]
# Can drop lat, lng, name and address as the number should identify the station along with it's location. Last updated can be dropped as it is not longer required as day of the week, hour and minute have been retained. Can also drop numbe of available bike stands - this can become a target feature later.

# %%
# Drop unneeded columns 
df.drop(['name', 'address', 'lng', 'lat', 'available_bike_stands', 'last_update'], axis=1, inplace = True)

# %%
# Change all columns to float64 for ML model
int_to_float = df[['available_bikes', 'bike_stands', 
                          'number', 'banking', 'weekday', 'hour', 'minute']]
for column in int_to_float:
    df[column] = df[column].astype('float64')

# %%
df.to_csv('05-13-03-19_results_cleaned.csv')

# %%
df.iloc[220]
# Out:
# available_bikes     0.0
# number              2.0
# bike_stands        20.0
# banking             1.0
# weekday             2.0
# hour                8.0
# minute             44.0
# Name: 220, dtype: float64
